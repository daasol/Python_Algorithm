# %%
#esc+M : markdown

# %% [markdown]
# # hello world
# ## hello world
# ### hello world
#
# 1. hello world
# 2. hello world
# 3. hello world
#
# - hello world
# - hello world
# * hello world
#
# * hello world
#
# > Hello world
# # 꺽쇠는 인용구
#
# hello world
# *hello* world : *별표하나는 이텔릭*
#
# **hello world** : **별표 두개는 볼드체**
#
#
# 라이브러리설치 !pip3 install
#
# 디렉터리 리스트 보기 !ls
#
# 파일 실행 (magic command) : %run 001.py

# %%
import random
random.randint(1, 10)
# Out:
# 6

# %% [markdown]
# ## 이미지를 업로드 하기
# ![%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C%20%281%29.jfif](attachment:%EB%8B%A4%EC%9A%B4%EB%A1%9C%EB%93%9C%20%281%29.jfif)
